# %%
# Introduction to Programming
# Assignment: Task 2
# The Problem
# In this task you should create a program that asks a user to enter their password, checks its length, and then verifies it further by asking for various characters from it.
# It should work like this. First, the user should be prompted to enter their password (do not worry that it appears on the screen). Then the program should check the length of the password, and if it is less than 9 characters long (so a length of 9 is OK, 8 is not OK), the user should be informed, and the program should exit.
# If the password is sufficiently long, the program should ask for three random letters from the password (as shown below). If any of these are given incorrectly, the program should exit immediately. (Do not worry if the program asks for the same letter more than once.)

entered_password = input("Enter your password: ")

size = len(entered_password)

if size < 9:
    print()
    print("Password too short.")
else:
    position_a = size // 5
    if position_a < 1:
        position_a = 1
    position_b = size * 3 // 4
    if position_b < 1:
        position_b = 1
    position_c = size - 2
    if position_c < 1:
        position_c = 1
    
    expected_a = entered_password[position_a - 1]
    expected_b = entered_password[position_b - 1]
    expected_c = entered_password[position_c - 1]
    
    response_a = input("Enter letter at position " + str(position_a) + ": ")
    print()
    match_a = response_a == expected_a
    
    if match_a:
        print("Correct")
        print()
        response_b = input("Enter letter at position " + str(position_b) + ": ")
        print()
        match_b = response_b == expected_b
        
        if match_b:
            print("Correct")
            print()
            response_c = input("Enter letter at position " + str(position_c) + ": ")
            print()
            match_c = response_c == expected_c
            
            if match_c:
                print("Correct")
                print()
                print("Security check passed.")
            else:
                print("Security check failed.")
        else:
            print("Security check failed.")
    else:
        print("Security check failed.")
# Out:
# Enter your password:  Sujal23456
# Enter letter at position 2:  u
# Correct
# Enter letter at position 7:  3
# Correct
# Enter letter at position 8:  4
# Correct
#
# Security check passed.
