# %%
#7 Modify your "Times Table" program so that the user enters the number of the table
#they require. This number should be between 0 and 12 inclusive.
while True:
    num = int(input("Enter a number to see its multiplication table from (0-12): "))

    if num < 0 or num > 12:
        print("Please enter a valid number between 0 and 12.")
        
    else:
        for i in range(0, 13):
            print(f"{i} * {num} = {i * num}")
        break
# Out:
# Enter a number to see its multiplication table from (0-12):  10
# 0 * 10 = 0
# 1 * 10 = 10
# 2 * 10 = 20
# 3 * 10 = 30
# 4 * 10 = 40
# 5 * 10 = 50
# 6 * 10 = 60
# 7 * 10 = 70
# 8 * 10 = 80
# 9 * 10 = 90
# 10 * 10 = 100
# 11 * 10 = 110
# 12 * 10 = 120
