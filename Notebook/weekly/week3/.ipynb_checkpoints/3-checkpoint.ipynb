# %%
password = input("Password (case sensitive): ")
confirm_password = input("Confirm password (case sensitive): ")

if 8 <= len(password) <= 12 and password == confirm_password:
    print("Password Set")
else:
    print("Error! Password Not Set")
# Out:
# Password (case sensitive):  jamal34
# Confirm password (case sensitive):  jamal34
# Error! Password Not Set
