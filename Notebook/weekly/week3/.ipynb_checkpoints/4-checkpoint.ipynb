# %%
#Modify your program again so that the chosen password cannot be one of a list of
#common passwords, defined thus:
#BAD_PASSWORDS = ['password', 'letmein', 'sesame', 'hello', 'justinbieber']

BAD_PASSWORDS = ['password', 'letmein', 'sesame', 'hello', 'justinbieber']
password = input("Password (case sensitive): ")
for bad in BAD_PASSWORDS:
    if password.strip().lower() == bad:
        print("Error! Password is too common.")
        break
# Out:
# Password (case sensitive):  letmein
# Error! Password is too common.
