# %%
# 8 Modify the "Times Table" again so that the user still enters the number of the table,
# but if this number is negative the table is printed backwards. So entering "-7"
# would produce the Seven Times Table starting at "12 times" down to "0 times".
#8
while True:
    number = int(input("Enter a number from 0-12:\nNegative number to print backwards: "))

    if number >= 0:
        for i in range(0, 13):
            print(f"{i} * {number} = {i * number}")
    else:
        for i in range(12, -1, -1):
            print(f"{i} * {abs(number)} = {i * abs(number)}")
    break
# Out:
# Enter a number from 0-12:
# Negative number to print backwards:  -9
# 12 * 9 = 108
# 11 * 9 = 99
# 10 * 9 = 90
# 9 * 9 = 81
# 8 * 9 = 72
# 7 * 9 = 63
# 6 * 9 = 54
# 5 * 9 = 45
# 4 * 9 = 36
# 3 * 9 = 27
# 2 * 9 = 18
# 1 * 9 = 9
# 0 * 9 = 0
