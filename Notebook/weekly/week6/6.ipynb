# %%
#6. Write a program that decrypts messages encoded as above.

def decode(text, space):
    original = ""
    for index in range(0, len(text), space):
        original = original + text[index]
    return original

encrypted = input("Encrypted text: ")
interval = int(input("Interval: "))
print("Original message:", decode(encrypted, interval))
# Out:
# Encrypted text:  hi my name is sujal
# Interval:  6
# Original message: hnsl
