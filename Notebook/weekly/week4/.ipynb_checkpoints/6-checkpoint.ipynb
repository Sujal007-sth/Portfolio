# %%
# 6. Write a program that takes a centigrade temperature and displays the equivalent in
# fahrenheit. The input should be a number followed by a letter C. The output should
# be in the same format.

user_input = input("Temperature in Celsius (like 30C): ")
c_value = float(user_input.replace("C", ""))
f_value = c_value * 1.8 + 32
print(f"{f_value}F")
# Out:
# Temperature in Celsius (like 30C):  45
# 113.0F
