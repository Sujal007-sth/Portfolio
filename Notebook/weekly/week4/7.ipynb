# %%
# 7. Write a program that reads 6 temperatures (in the same format as before), and
# displays the maximum, minimum, and mean of the values.
# Hint: You should know there are built-in functions for max and min. If you hunt, you
# might also find one for the mean.

from statistics import mean

temps = []
for count in range(6):
    entry = input("Temp " + str(count+1) + " (like 20C): ")
    value = float(entry.replace("C", ""))
    temps.append(value)

print("Max:", max(temps), "C")
print("Min:", min(temps), "C")
print("Mean:", mean(temps), "C")
# Out:
# Temp 1 (like 20C):  34
# Temp 2 (like 20C):  36
# Temp 3 (like 20C):  38
# Temp 4 (like 20C):  39
# Temp 5 (like 20C):  45
# Temp 6 (like 20C):  40
# Max: 45.0 C
# Min: 34.0 C
# Mean: 38.666666666666664 C
